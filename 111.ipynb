# %%
[
    {
        "id": "1019",
        "name": "Surebet247",
        "product": "410",
        "category": "BETTING, LOTTERY AND GAMING",
        "division": "A",
        "payment_items": [],
    },
    {
        "id": "1344",
        "name": "Superior Bet",
        "product": "410",
        "category": "BETTING, LOTTERY AND GAMING",
        "division": "A",
        "payment_items": [],
    },
    {
        "id": "1449",
        "name": "Winners Golden Bet",
        "product": "410",
        "category": "BETTING, LOTTERY AND GAMING",
        "division": "A",
        "payment_items": [],
    },
    {
        "id": "1986",
        "name": "Royalbet",
        "product": "410",
        "category": "BETTING, LOTTERY AND GAMING",
        "division": "A",
        "payment_items": [],
    },
    {
        "id": "2129",
        "name": "Loving Bet",
        "product": "410",
        "category": "BETTING, LOTTERY AND GAMING",
        "division": "A",
        "payment_items": [],
    },
    {
        "id": "2216",
        "name": "90mbet.com",
        "product": "410",
        "category": "BETTING, LOTTERY AND GAMING",
        "division": "A",
        "payment_items": [],
    },
    {
        "id": "1XBET",
        "name": "1xBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
        "convenienceFee": "30.00",
    },
    {
        "id": "ACCESSBET",
        "name": "Accessbet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "BANGBET",
        "name": "BangBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "BET9JA",
        "name": "Bet9ja",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
        "convenienceFee": "30.00",
    },
    {
        "id": "BETKING",
        "name": "BetKing",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
        "convenienceFee": "30.00",
    },
    {
        "id": "BETLAND",
        "name": "BetLand",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "BETWAY",
        "name": "BetWay",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
        "convenienceFee": "30.00",
    },
    {
        "id": "CLOUDBET",
        "name": "CloudBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "HALLABET",
        "name": "Hallabet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "LIVESCOREBET",
        "name": "LiveScoreBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "MERRYBET",
        "name": "MerryBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "NAIJABET",
        "name": "NaijaBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "NAIRABET",
        "name": "NairaBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "SPORTYBET",
        "name": "Sportybet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "SUPABET",
        "name": "SupaBet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "SUREBET",
        "name": "Surebet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "WINNERS_GOLDEN_BET",
        "name": "Winners Golden Bet",
        "product": "408",
        "category": "BETTTING, LOTTERY AND GAMING",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "airng",
        "name": "AIRTEL",
        "product": "423",
        "category": "Airtime",
        "division": "C",
        "payment_items": [
            {
                "id": "5",
                "code": "2",
                "amount": "0",
                "itemFee": "0",
                "billerid": "airng",
                "division": "C",
                "pictureId": "87",
                "productId": "423",
                "sortOrder": "4",
                "billerType": "MO",
                "categoryid": "3",
                "createdDate": "2022-10-18 10:11:43",
                "paymentCode": "airng",
                "currencyCode": "566",
                "isAmountFixed": "false",
                "paymentitemid": "423",
                "currencySymbol": "NGN",
                "paymentitemname": "AIRNG",
                "payDirectitemCode": "airng",
                "itemCurrencySymbol": "NGN",
            }
        ],
    },
    {
        "id": "AIRTEL_VBANK",
        "name": "AIRTEL",
        "product": "424",
        "category": "AIRTIME",
        "division": "G",
        "payment_items": [],
    },
    {
        "id": "CX_MTN",
        "name": "MTN",
        "product": "421",
        "category": "AIRTIME",
        "division": "G",
        "payment_items": [],
    },
    {
        "id": "eting",
        "name": "9MOBILE",
        "product": "422",
        "category": "AIRTIME",
        "division": "C",
        "payment_items": [
            {
                "id": "4",
                "code": "2",
                "amount": "0",
                "itemFee": "0",
                "billerid": "eting",
                "division": "C",
                "pictureId": "87",
                "productId": "422",
                "sortOrder": "4",
                "billerType": "MO",
                "categoryid": "3",
                "createdDate": "2022-10-18 10:11:39",
                "paymentCode": "eting",
                "currencyCode": "566",
                "isAmountFixed": "false",
                "paymentitemid": "422",
                "currencySymbol": "NGN",
                "paymentitemname": "ETING",
                "payDirectitemCode": "eting",
                "itemCurrencySymbol": "NGN",
            }
        ],
    },
    {
        "id": "glong",
        "name": "GLO",
        "product": "424",
        "category": "AIRTIME",
        "division": "C",
        "payment_items": [
            {
                "id": "3",
                "code": "2",
                "amount": "0",
                "itemFee": "0",
                "billerid": "glong",
                "division": "C",
                "pictureId": "87",
                "productId": "424",
                "sortOrder": "4",
                "billerType": "MO",
                "categoryid": "3",
                "createdDate": "2022-10-18 10:11:35",
                "paymentCode": "glong",
                "currencyCode": "566",
                "isAmountFixed": "false",
                "paymentitemid": "424",
                "currencySymbol": "NGN",
                "paymentitemname": "GLONG",
                "payDirectitemCode": "glong",
                "itemCurrencySymbol": "NGN",
            }
        ],
    },
    {
        "id": "GLO_VBANK",
        "name": "GLO",
        "product": "424",
        "category": "AIRTIME",
        "division": "G",
        "payment_items": [],
    },
    {
        "id": "mtn",
        "name": "MTN",
        "product": "421",
        "category": "AIRTIME",
        "division": "B",
        "payment_items": [],
    },
    {
        "id": "MTN_NIGERIA",
        "name": "MTN",
        "product": "426",
        "category": "AIRTIME",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "AIRTEL_VBANK_DATA",
        "name": "AIRTEL",
        "product": "426",
        "category": "Data",
        "division": "G",
        "payment_items": [],
    },
    {
        "id": "CX_MTN_data",
        "name": "MTN",
        "product": "419",
        "category": "Data",
        "division": "G",
        "payment_items": [],
    },
    {
        "id": "GLO_VBANK_DATA",
        "name": "GLO",
        "product": "426",
        "category": "Data",
        "division": "G",
        "payment_items": [
            {
                "id": "17",
                "code": "2",
                "amount": "0",
                "itemFee": "0",
                "billerid": "GLO_VBANK_DATA",
                "division": "G",
                "pictureId": "87",
                "productId": "426",
                "sortOrder": "4",
                "billerType": "MO",
                "categoryid": "2",
                "createdDate": "2024-01-09 11:24:35",
                "paymentCode": "GLO_VBANK_DATA",
                "currencyCode": "566",
                "isAmountFixed": "false",
                "paymentitemid": "426",
                "currencySymbol": "NGN",
                "paymentitemname": "GLO_VBANK_DATA",
                "payDirectitemCode": "GLO_VBANK_DATA",
                "itemCurrencySymbol": "NGN",
            }
        ],
    },
    {
        "id": "mtn_data",
        "name": "MTN",
        "product": "419",
        "category": "Data",
        "division": "B",
        "payment_items": [],
    },
    {
        "id": "MTN_NIGERIA_DATA",
        "name": "MTN",
        "product": "426",
        "category": "Data",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "dstv",
        "name": "DSTV Subscription",
        "product": "399",
        "category": "Cable TV",
        "division": "B",
        "payment_items": [],
    },
    {
        "id": "dstvshowmax",
        "name": "Showmax",
        "product": "407",
        "category": "Cable TV",
        "division": "B",
        "payment_items": [],
    },
    {
        "id": "JAMB_CORALPAY",
        "name": "JAMB",
        "product": "408",
        "category": "Education",
        "division": "F",
        "payment_items": [],
    },
    {
        "id": "mtnng",
        "name": "MTN",
        "product": "425",
        "category": "Internet Subscription",
        "division": "C",
        "payment_items": [
            {
                "id": "6",
                "code": "2",
                "amount": "0",
                "itemFee": "0",
                "billerid": "mtnng",
                "division": "C",
                "pictureId": "87",
                "productId": "425",
                "sortOrder": "4",
                "billerType": "MO",
                "categoryid": "3",
                "createdDate": "2022-10-18 10:11:47",
                "paymentCode": "mtnng",
                "currencyCode": "566",
                "isAmountFixed": "false",
                "paymentitemid": "425",
                "currencySymbol": "NGN",
                "paymentitemname": "MTNNG",
                "payDirectitemCode": "mtnng",
                "itemCurrencySymbol": "NGN",
            }
        ],
    },
]
